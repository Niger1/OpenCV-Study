# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

cat = cv2.imread('cat.jpg')

# cv2.imshow('cat',cat)


b = cat[:,:,0]
g = cat[:,:,1]
r = cat[:,:,2]

# cv2.imshow('b',b)
# cv2.imshow('g',g)
# cv2.imshow('r',r)

cat[:,:,0]=0
cv2.imshow('b0',cat)  #通道b设置为0 图片是黄色的
cat[:,:,1]=0
cv2.imshow('b0g0',cat)   #通道b，g设置为0 图片只剩红色
cat[:,:,2]=0
# cv2.imshow('b0g0r0',cat)    #通道b，g，r设置为0




cv2.waitKey()
cv2.destroyAllWindows()
